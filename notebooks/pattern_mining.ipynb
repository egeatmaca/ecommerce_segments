# %%
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import pandas.io.sql as sqlio
import os
from dotenv import load_dotenv
import datetime as dt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier, plot_tree
import torch
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader, TensorDataset
import shap
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.cluster import KMeans, Birch
from sklearn.metrics import silhouette_score
from sklearn.pipeline import Pipeline
from hdbscan import HDBSCAN
import statsmodels.api as sm 
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import pickle as pkl
import json
import random

# %%
import sys
sys.path.insert(0, '../src/torch_helpers')

from autoencoder import AutoEncoder, AETrainer
from encoding_classifier import EncodingClassifier, ClfTrainer
from lrp import LinearLRP

# %%
RANDOM_STATE = 42

random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)

# %% [markdown]
# # EDA

# %%
# Curry function to initialize postgres engine and return read_query function

def make_read_query(protocol=None, user=None, password=None, host=None, port=None, db=None):
    load_dotenv()
    
    protocol = protocol if protocol else 'postgresql+psycopg2'
    user = user if user else os.environ.get('POSTGRES_USER')
    password = password if password else os.environ.get('POSTGRES_PASSWORD')
    host = host if host else 'localhost'
    port = port if port else 5432
    db = db if db else os.environ.get('POSTGRES_DB')
    
    db_url = f'{protocol}://{user}:{password}@{host}:{port}/{db}'
    engine = create_engine(db_url)

    def read_query(query, verbose=True):
        if verbose:
            print(query, '\n')
            
        with engine.connect() as conn:
            df = sqlio.read_sql_query(query, conn)

        return df

    return read_query

# %%
read_query = make_read_query()

# %%
users_enriched = read_query("SELECT * FROM users_enriched")
users_enriched.head()
# Out:
# SELECT * FROM users_enriched
#       id  age gender         country          city traffic_source  \
# 0  56219   60      F   United States  Philadelphia       Facebook
# 1   9418   69      F  United Kingdom       Cardiff         Search
# 2  21731   65      F           China        Harbin          Email
# 3  39594   17      M           China      Shenzhen         Search
# 4   2000   30      F           China         Hefei         Search
#
#            created_at first_order_timestamp last_order_timestamp  \
# 0 2019-01-02 00:06:00   2021-05-27 23:07:12  2021-05-27 23:07:12
# 1 2019-01-02 00:36:00   2021-07-30 12:35:12  2023-04-21 14:50:59
# 2 2019-01-02 01:47:00   2023-09-17 22:23:37  2023-09-17 22:23:37
# 3 2019-01-02 03:00:00   2019-02-11 03:06:43  2019-10-25 02:29:03
# 4 2019-01-02 03:19:00                   NaT                  NaT
#
#    days_to_activation  ...                   fav_category  fav_cat_purchases  \
# 0               876.0  ...                          Jeans                1.0
# 1               940.0  ...              Outerwear & Coats                1.0
# 2              1719.0  ...              Blazers & Jackets                1.0
# 3                40.0  ...  Fashion Hoodies & Sweatshirts                1.0
# 4                 NaN  ...                           None                NaN
#
#    fav_cat_avg_item_value  fav_cat_freq_strength  fav_cat_spending_strength  \
# 0                   74.99                   0.00                   0.000000
# 1                  399.00                   0.50                   0.900677
# 2                  169.98                   0.25                   0.696811
# 3                   51.96                   0.50                   0.722168
# 4                     NaN                    NaN                        NaN
#
#                                          order_items  loyalty_segment  \
# 0  {"(70373,\"WranglerÂ® Booty Up Stretch Jean fo...             None
# 1  {"(90353,\"Colleen Skirt Slip\",Women,Intimate...             None
# 2  {"(27173,\"Modadorn New Arrivals Spring & fall...             None
# 3  {"(49470,\"Billabong Men's Semi-Button Up Stri...             None
# 4                                               None             None
#
#    order_value_segment  category_choice_segment  lifetime_status
# 0                 None                     None             None
# 1                 None                     None             None
# 2                 None                     None             None
# 3                 None                     None             None
# 4                 None                     None             None
#
# [5 rows x 32 columns]

# %%
order_items_enriched = read_query("SELECT * FROM order_items_enriched")
order_items_enriched.head()
# Out:
# SELECT * FROM order_items_enriched
#    id  order_id  user_id  product_id  inventory_item_id      status  \
# 0   1         1        1        2953                  3     Shipped
# 1   2         1        1        4731                  7     Shipped
# 2   3         1        1        7656                  9     Shipped
# 3   4         2        2       25774                 11    Complete
# 4   5         3        3       22308                 13  Processing
#
#            created_at          shipped_at        delivered_at returned_at  \
# 0 2022-07-20 10:32:05 2022-07-20 16:42:00                 NaT         NaT
# 1 2022-07-20 11:05:38 2022-07-20 16:42:00                 NaT         NaT
# 2 2022-07-19 11:29:28 2022-07-20 16:42:00                 NaT         NaT
# 3 2022-02-20 10:28:57 2022-02-22 12:23:00 2022-02-23 18:29:00         NaT
# 4 2023-04-23 09:04:57                 NaT                 NaT         NaT
#
#    ...   product_category  product_department    product_brand  \
# 0  ...             Active               Women   Tommy Hilfiger
# 1  ...              Jeans               Women      Joe's Jeans
# 2  ...  Blazers & Jackets               Women  eVogues Apparel
# 3  ...          Underwear                 Men     Tommy Bahama
# 4  ...              Pants                 Men          Dockers
#
#                                         product_name  \
# 0          Tommy Hilfiger Women's 3 Pack Sports Crew
# 1                   Joe's Jeans Women's Skinny Jeans
# 2  Plus size Button Closure Cropped Bolero Jacket...
# 3            Tommy Bahama Tropical Print Boxer Short
# 4  Dockers Men's Limited Offer D2 Stretch Khaki Pant
#
#                            distribution_center user_age user_gender  \
# 0                                   Memphis TN       62           F
# 1  Port Authority of New York/New Jersey NY/NJ       62           F
# 2                               New Orleans LA       62           F
# 3                               Los Angeles CA       65           M
# 4                              Philadelphia PA       16           M
#
#      user_county         user_city user_traffic_source
# 0    South Korea      Bucheon City              Search
# 1    South Korea      Bucheon City              Search
# 2    South Korea      Bucheon City              Search
# 3         Brasil            Franca             Organic
# 4  United States  Hallandale Beach             Organic
#
# [5 rows x 22 columns]

# %%
order_items_enriched.product_category.unique()
# Out:
# array(['Active', 'Jeans', 'Blazers & Jackets', 'Underwear', 'Pants',
#        'Sleep & Lounge', 'Swim', 'Sweaters', 'Skirts', 'Shorts',
#        'Accessories', 'Fashion Hoodies & Sweatshirts',
#        'Suits & Sport Coats', 'Tops & Tees', 'Socks', 'Outerwear & Coats',
#        'Dresses', 'Jumpsuits & Rompers', 'Maternity', 'Intimates',
#        'Pants & Capris', 'Leggings', 'Plus', 'Socks & Hosiery', 'Suits',
#        'Clothing Sets'], dtype=object)

# %%
order_items_enriched.status.value_counts()
# Out:
# status
# Shipped       54440
# Complete      45609
# Processing    36388
# Cancelled     27090
# Returned      18232
# Name: count, dtype: int64

# %%
repeat_purchasers = users_enriched.loc[users_enriched.n_orders>1]
repeat_purchasers_idx = list(set(order_items_enriched.user_id).intersection(repeat_purchasers.id))

# %%
order_items_filtered = order_items_enriched.loc[order_items_enriched.user_id.isin(repeat_purchasers_idx)]\
                                          .loc[order_items_enriched.user_gender=='F']\
                                          .loc[~order_items_enriched.status.isin(['Cancelled', 'Returned'])]

user_sequences = order_items_filtered.sort_values('created_at')\
                                    .groupby('user_id')['product_category'].apply(list)\
                                    .tolist()

# %%
user_sequences
# Out:
# [['Sleep & Lounge', 'Jeans', 'Jumpsuits & Rompers', 'Swim', 'Jeans'],
#  ['Intimates', 'Maternity'],
#  ['Tops & Tees', 'Leggings'],
#  ['Socks & Hosiery'],
#  ['Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Fashion Hoodies & Sweatshirts',
#   'Dresses',
#   'Swim',
#   'Sweaters',
#   'Shorts',
#   'Intimates',
#   'Intimates'],
#  ['Tops & Tees', 'Accessories'],
#  ['Plus',
#   'Sleep & Lounge',
#   'Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Jeans',
#   'Socks & Hosiery',
#   'Socks & Hosiery'],
#  ['Dresses', 'Suits', 'Accessories', 'Leggings', 'Shorts'],
#  ['Shorts', 'Suits', 'Pants & Capris'],
#  ['Pants & Capris', 'Intimates'],
#  ['Sleep & Lounge', 'Outerwear & Coats', 'Active'],
#  ['Plus',
#   'Socks & Hosiery',
#   'Sweaters',
#   'Intimates',
#   'Leggings',
#   'Intimates',
#   'Plus'],
#  ['Shorts', 'Intimates', 'Pants & Capris'],
#  ['Jeans', 'Tops & Tees'],
#  ['Shorts', 'Leggings', 'Intimates'],
#  ['Intimates', 'Plus', 'Intimates'],
#  ['Accessories', 'Blazers & Jackets'],
#  ['Socks & Hosiery', 'Sleep & Lounge'],
#  ['Plus', 'Pants & Capris'],
#  ['Suits', 'Maternity', 'Swim', 'Pants & Capris', 'Dresses'],
#  ['Intimates'],
#  ['Active', 'Socks & Hosiery'],
#  ['Active', 'Leggings', 'Shorts', 'Swim', 'Intimates'],
#  ['Dresses',
#   'Sleep & Lounge',
#   'Sleep & Lounge',
#   'Intimates',
#   'Tops & Tees',
#   'Fashion Hoodies & Sweatshirts',
#   'Sleep & Lounge'],
#  ['Maternity', 'Intimates', 'Swim', 'Plus'],
#  ['Sweaters'],
#  ['Sweaters', 'Sleep & Lounge', 'Plus'],
#  ['Skirts', 'Leggings'],
#  ['Intimates'],
#  ['Jeans', 'Accessories', 'Outerwear & Coats'],
#  ['Maternity', 'Dresses'],
#  ['Intimates', 'Dresses', 'Intimates', 'Outerwear & Coats', 'Swim'],
#  ['Intimates', 'Plus', 'Tops & Tees'],
#  ['Intimates', 'Leggings'],
#  ['Outerwear & Coats', 'Clothing Sets', 'Jeans'],
#  ['Skirts', 'Intimates', 'Intimates', 'Outerwear & Coats'],
#  ['Leggings',
#   'Plus',
#   'Blazers & Jackets',
#   'Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Pants & Capris'],
#  ['Tops & Tees', 'Outerwear & Coats', 'Intimates', 'Sleep & Lounge', 'Skirts'],
#  ['Dresses', 'Maternity', 'Fashion Hoodies & Sweatshirts'],
#  ['Blazers & Jackets', 'Socks & Hosiery'],
#  ['Clothing Sets', 'Skirts', 'Swim', 'Jeans'],
#  ['Tops & Tees', 'Sweaters', 'Tops & Tees', 'Swim'],
#  ['Intimates', 'Maternity', 'Swim', 'Maternity', 'Maternity'],
#  ['Skirts',
#   'Active',
#   'Dresses',
#   'Fashion Hoodies & Sweatshirts',
#   'Swim',
#   'Outerwear & Coats',
#   'Sweaters',
#   'Skirts'],
#  ['Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Pants & Capris', 'Maternity', 'Tops & Tees', 'Maternity'],
#  ['Dresses', 'Sleep & Lounge'],
#  ['Tops & Tees'],
#  ['Active', 'Shorts', 'Intimates'],
#  ['Suits', 'Sleep & Lounge', 'Tops & Tees', 'Sweaters', 'Intimates', 'Active'],
#  ['Outerwear & Coats', 'Outerwear & Coats'],
#  ['Sweaters', 'Blazers & Jackets'],
#  ['Intimates', 'Intimates', 'Jeans'],
#  ['Plus', 'Socks & Hosiery', 'Intimates'],
#  ['Fashion Hoodies & Sweatshirts', 'Intimates', 'Active'],
#  ['Fashion Hoodies & Sweatshirts', 'Dresses'],
#  ['Swim', 'Sleep & Lounge'],
#  ['Sleep & Lounge'],
#  ['Tops & Tees', 'Sleep & Lounge', 'Blazers & Jackets', 'Plus'],
#  ['Jeans'],
#  ['Sweaters', 'Sleep & Lounge', 'Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Dresses', 'Intimates'],
#  ['Pants & Capris',
#   'Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Outerwear & Coats'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Shorts',
#   'Maternity',
#   'Pants & Capris',
#   'Accessories'],
#  ['Intimates', 'Intimates', 'Plus'],
#  ['Sleep & Lounge', 'Sleep & Lounge', 'Sweaters', 'Swim', 'Outerwear & Coats'],
#  ['Accessories', 'Dresses', 'Intimates'],
#  ['Sweaters', 'Tops & Tees'],
#  ['Outerwear & Coats', 'Jeans', 'Maternity', 'Dresses', 'Dresses'],
#  ['Intimates', 'Intimates', 'Jeans'],
#  ['Outerwear & Coats', 'Jeans'],
#  ['Suits', 'Fashion Hoodies & Sweatshirts', 'Swim'],
#  ['Socks & Hosiery', 'Blazers & Jackets'],
#  ['Dresses', 'Intimates', 'Accessories', 'Shorts', 'Intimates', 'Shorts'],
#  ['Tops & Tees'],
#  ['Tops & Tees', 'Skirts', 'Swim'],
#  ['Dresses', 'Jeans', 'Dresses', 'Jeans'],
#  ['Swim'],
#  ['Intimates', 'Intimates'],
#  ['Intimates'],
#  ['Blazers & Jackets'],
#  ['Active', 'Dresses'],
#  ['Sleep & Lounge', 'Sweaters', 'Maternity', 'Dresses'],
#  ['Shorts', 'Intimates'],
#  ['Swim',
#   'Intimates',
#   'Plus',
#   'Accessories',
#   'Fashion Hoodies & Sweatshirts',
#   'Swim'],
#  ['Outerwear & Coats', 'Fashion Hoodies & Sweatshirts', 'Shorts'],
#  ['Fashion Hoodies & Sweatshirts', 'Swim'],
#  ['Socks & Hosiery', 'Leggings', 'Blazers & Jackets', 'Accessories'],
#  ['Skirts', 'Plus', 'Jumpsuits & Rompers', 'Sleep & Lounge'],
#  ['Pants & Capris',
#   'Sleep & Lounge',
#   'Maternity',
#   'Socks & Hosiery',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Shorts', 'Active', 'Active', 'Fashion Hoodies & Sweatshirts'],
#  ['Intimates', 'Accessories', 'Maternity', 'Jeans', 'Maternity'],
#  ['Tops & Tees', 'Pants & Capris', 'Plus'],
#  ['Sweaters', 'Dresses', 'Maternity'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Socks & Hosiery',
#   'Accessories',
#   'Intimates'],
#  ['Plus'],
#  ['Shorts', 'Leggings'],
#  ['Intimates',
#   'Jumpsuits & Rompers',
#   'Accessories',
#   'Socks & Hosiery',
#   'Sleep & Lounge'],
#  ['Swim', 'Blazers & Jackets', 'Intimates'],
#  ['Shorts', 'Swim', 'Plus', 'Accessories', 'Jeans'],
#  ['Shorts', 'Blazers & Jackets'],
#  ['Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Outerwear & Coats',
#   'Intimates',
#   'Tops & Tees',
#   'Intimates',
#   'Swim',
#   'Tops & Tees',
#   'Sweaters'],
#  ['Dresses', 'Swim', 'Outerwear & Coats', 'Blazers & Jackets'],
#  ['Pants & Capris', 'Leggings', 'Sweaters'],
#  ['Swim', 'Jeans'],
#  ['Accessories', 'Suits'],
#  ['Maternity', 'Intimates', 'Swim'],
#  ['Intimates', 'Shorts'],
#  ['Swim', 'Outerwear & Coats', 'Dresses', 'Outerwear & Coats'],
#  ['Maternity', 'Accessories', 'Intimates', 'Sweaters'],
#  ['Maternity', 'Suits', 'Plus', 'Maternity'],
#  ['Pants & Capris', 'Jeans', 'Tops & Tees', 'Shorts', 'Maternity'],
#  ['Shorts', 'Intimates'],
#  ['Intimates', 'Jeans'],
#  ['Intimates'],
#  ['Maternity', 'Swim', 'Blazers & Jackets'],
#  ['Plus', 'Shorts'],
#  ['Clothing Sets', 'Maternity', 'Maternity'],
#  ['Maternity', 'Active', 'Sleep & Lounge', 'Shorts'],
#  ['Skirts', 'Sweaters', 'Plus'],
#  ['Intimates',
#   'Skirts',
#   'Sleep & Lounge',
#   'Intimates',
#   'Swim',
#   'Shorts',
#   'Tops & Tees'],
#  ['Intimates', 'Accessories', 'Intimates'],
#  ['Accessories'],
#  ['Maternity', 'Outerwear & Coats'],
#  ['Blazers & Jackets',
#   'Suits',
#   'Active',
#   'Maternity',
#   'Shorts',
#   'Pants & Capris'],
#  ['Active', 'Plus'],
#  ['Sleep & Lounge', 'Fashion Hoodies & Sweatshirts'],
#  ['Fashion Hoodies & Sweatshirts'],
#  ['Socks & Hosiery'],
#  ['Shorts', 'Fashion Hoodies & Sweatshirts', 'Fashion Hoodies & Sweatshirts'],
#  ['Intimates', 'Leggings'],
#  ['Plus', 'Sleep & Lounge', 'Intimates'],
#  ['Socks & Hosiery', 'Intimates', 'Sweaters', 'Leggings'],
#  ['Jumpsuits & Rompers', 'Socks & Hosiery', 'Swim', 'Active'],
#  ['Jeans', 'Intimates'],
#  ['Jeans', 'Socks & Hosiery', 'Accessories'],
#  ['Sleep & Lounge'],
#  ['Intimates', 'Socks & Hosiery', 'Sweaters'],
#  ['Pants & Capris',
#   'Swim',
#   'Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Plus',
#   'Intimates'],
#  ['Fashion Hoodies & Sweatshirts'],
#  ['Sleep & Lounge', 'Maternity', 'Intimates', 'Tops & Tees'],
#  ['Socks & Hosiery', 'Swim'],
#  ['Dresses'],
#  ['Shorts', 'Skirts', 'Sweaters', 'Maternity'],
#  ['Maternity'],
#  ['Intimates', 'Active', 'Swim'],
#  ['Sweaters', 'Active', 'Pants & Capris', 'Blazers & Jackets'],
#  ['Intimates', 'Maternity'],
#  ['Intimates', 'Sleep & Lounge'],
#  ['Sweaters', 'Active', 'Outerwear & Coats', 'Jeans', 'Blazers & Jackets'],
#  ['Leggings', 'Fashion Hoodies & Sweatshirts'],
#  ['Skirts', 'Sweaters'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Jeans',
#   'Sleep & Lounge',
#   'Maternity',
#   'Jeans'],
#  ['Jeans', 'Suits'],
#  ['Plus', 'Intimates', 'Fashion Hoodies & Sweatshirts', 'Suits'],
#  ['Intimates', 'Pants & Capris'],
#  ['Dresses',
#   'Skirts',
#   'Fashion Hoodies & Sweatshirts',
#   'Accessories',
#   'Suits'],
#  ['Maternity', 'Blazers & Jackets'],
#  ['Maternity', 'Tops & Tees', 'Socks & Hosiery'],
#  ['Maternity', 'Suits'],
#  ['Shorts', 'Socks & Hosiery', 'Maternity', 'Skirts'],
#  ['Jeans', 'Tops & Tees', 'Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Tops & Tees'],
#  ['Intimates', 'Shorts'],
#  ['Tops & Tees', 'Accessories'],
#  ['Leggings', 'Socks & Hosiery', 'Maternity'],
#  ['Accessories',
#   'Tops & Tees',
#   'Intimates',
#   'Jumpsuits & Rompers',
#   'Intimates',
#   'Jeans'],
#  ['Leggings', 'Dresses'],
#  ['Intimates'],
#  ['Intimates', 'Skirts'],
#  ['Accessories', 'Maternity'],
#  ['Socks & Hosiery', 'Pants & Capris'],
#  ['Dresses', 'Blazers & Jackets', 'Intimates', 'Jeans', 'Outerwear & Coats'],
#  ['Outerwear & Coats', 'Sleep & Lounge'],
#  ['Plus', 'Socks & Hosiery'],
#  ['Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Plus', 'Tops & Tees', 'Intimates', 'Sleep & Lounge', 'Intimates'],
#  ['Tops & Tees', 'Maternity', 'Jeans', 'Jeans', 'Sweaters'],
#  ['Suits', 'Plus'],
#  ['Shorts', 'Intimates'],
#  ['Intimates', 'Sweaters', 'Fashion Hoodies & Sweatshirts'],
#  ['Swim', 'Leggings'],
#  ['Swim', 'Suits', 'Jeans'],
#  ['Tops & Tees',
#   'Sleep & Lounge',
#   'Outerwear & Coats',
#   'Socks & Hosiery',
#   'Sleep & Lounge',
#   'Sleep & Lounge',
#   'Maternity'],
#  ['Active', 'Swim'],
#  ['Plus', 'Sleep & Lounge', 'Skirts', 'Sleep & Lounge'],
#  ['Swim', 'Maternity', 'Maternity', 'Shorts', 'Accessories', 'Shorts'],
#  ['Maternity', 'Intimates', 'Accessories', 'Fashion Hoodies & Sweatshirts'],
#  ['Intimates', 'Blazers & Jackets'],
#  ['Jeans', 'Intimates', 'Maternity'],
#  ['Outerwear & Coats',
#   'Active',
#   'Dresses',
#   'Fashion Hoodies & Sweatshirts',
#   'Swim'],
#  ['Blazers & Jackets', 'Swim'],
#  ['Accessories', 'Active'],
#  ['Intimates', 'Skirts', 'Pants & Capris'],
#  ['Dresses', 'Jeans', 'Jeans'],
#  ['Shorts', 'Shorts'],
#  ['Shorts', 'Sleep & Lounge', 'Active'],
#  ['Socks & Hosiery'],
#  ['Pants & Capris'],
#  ['Active'],
#  ['Plus', 'Pants & Capris'],
#  ['Suits'],
#  ['Active', 'Intimates', 'Sleep & Lounge', 'Socks & Hosiery', 'Swim'],
#  ['Intimates', 'Intimates', 'Skirts', 'Dresses', 'Skirts'],
#  ['Tops & Tees', 'Socks & Hosiery'],
#  ['Intimates', 'Active'],
#  ['Fashion Hoodies & Sweatshirts', 'Tops & Tees', 'Active'],
#  ['Suits', 'Swim', 'Swim', 'Plus'],
#  ['Socks & Hosiery', 'Swim', 'Sweaters'],
#  ['Plus', 'Plus'],
#  ['Skirts'],
#  ['Sleep & Lounge', 'Accessories'],
#  ['Swim', 'Maternity'],
#  ['Swim',
#   'Fashion Hoodies & Sweatshirts',
#   'Fashion Hoodies & Sweatshirts',
#   'Tops & Tees',
#   'Pants & Capris'],
#  ['Pants & Capris', 'Sweaters', 'Pants & Capris', 'Socks & Hosiery'],
#  ['Leggings', 'Jeans'],
#  ['Maternity', 'Jeans'],
#  ['Sweaters', 'Intimates'],
#  ['Active', 'Intimates'],
#  ['Intimates',
#   'Maternity',
#   'Intimates',
#   'Sleep & Lounge',
#   'Intimates',
#   'Jeans',
#   'Plus',
#   'Maternity'],
#  ['Tops & Tees', 'Sweaters', 'Shorts', 'Swim', 'Shorts'],
#  ['Sleep & Lounge'],
#  ['Outerwear & Coats'],
#  ['Intimates', 'Fashion Hoodies & Sweatshirts'],
#  ['Maternity', 'Pants & Capris', 'Intimates', 'Dresses'],
#  ['Jeans', 'Outerwear & Coats', 'Fashion Hoodies & Sweatshirts'],
#  ['Plus',
#   'Dresses',
#   'Intimates',
#   'Maternity',
#   'Intimates',
#   'Jeans',
#   'Outerwear & Coats'],
#  ['Socks & Hosiery', 'Skirts', 'Intimates'],
#  ['Dresses', 'Intimates'],
#  ['Sleep & Lounge'],
#  ['Sweaters', 'Plus', 'Maternity'],
#  ['Fashion Hoodies & Sweatshirts', 'Plus', 'Sweaters', 'Active'],
#  ['Jumpsuits & Rompers', 'Accessories', 'Plus'],
#  ['Intimates',
#   'Outerwear & Coats',
#   'Sleep & Lounge',
#   'Leggings',
#   'Swim',
#   'Shorts'],
#  ['Active', 'Intimates', 'Sleep & Lounge', 'Accessories', 'Intimates'],
#  ['Shorts',
#   'Pants & Capris',
#   'Sleep & Lounge',
#   'Maternity',
#   'Tops & Tees',
#   'Blazers & Jackets'],
#  ['Socks & Hosiery', 'Active'],
#  ['Tops & Tees', 'Intimates', 'Fashion Hoodies & Sweatshirts'],
#  ['Swim'],
#  ['Plus', 'Pants & Capris', 'Dresses', 'Pants & Capris', 'Intimates'],
#  ['Socks & Hosiery', 'Blazers & Jackets', 'Swim'],
#  ['Accessories', 'Sweaters'],
#  ['Accessories', 'Shorts', 'Outerwear & Coats'],
#  ['Intimates', 'Accessories', 'Outerwear & Coats'],
#  ['Tops & Tees', 'Jeans'],
#  ['Intimates'],
#  ['Socks & Hosiery', 'Plus', 'Intimates'],
#  ['Plus', 'Pants & Capris'],
#  ['Intimates', 'Intimates'],
#  ['Tops & Tees'],
#  ['Sleep & Lounge', 'Socks & Hosiery'],
#  ['Jeans', 'Jeans'],
#  ['Swim', 'Intimates'],
#  ['Sleep & Lounge', 'Dresses', 'Intimates', 'Maternity', 'Shorts', 'Jeans'],
#  ['Fashion Hoodies & Sweatshirts', 'Maternity', 'Sweaters'],
#  ['Accessories', 'Jumpsuits & Rompers'],
#  ['Socks & Hosiery', 'Socks & Hosiery'],
#  ['Swim', 'Tops & Tees', 'Intimates', 'Dresses'],
#  ['Outerwear & Coats', 'Intimates'],
#  ['Intimates', 'Fashion Hoodies & Sweatshirts', 'Jeans'],
#  ['Intimates', 'Leggings', 'Socks & Hosiery'],
#  ['Socks & Hosiery', 'Sleep & Lounge'],
#  ['Socks & Hosiery', 'Maternity', 'Shorts', 'Dresses'],
#  ['Sleep & Lounge', 'Maternity', 'Active'],
#  ['Pants & Capris', 'Intimates', 'Intimates', 'Intimates'],
#  ['Sleep & Lounge', 'Tops & Tees'],
#  ['Active', 'Intimates'],
#  ['Jeans', 'Sweaters'],
#  ['Accessories', 'Dresses', 'Maternity', 'Dresses', 'Sweaters'],
#  ['Intimates', 'Tops & Tees'],
#  ['Pants & Capris', 'Tops & Tees', 'Plus'],
#  ['Dresses', 'Plus', 'Swim', 'Jeans'],
#  ['Tops & Tees', 'Dresses', 'Outerwear & Coats'],
#  ['Dresses', 'Outerwear & Coats'],
#  ['Socks & Hosiery', 'Maternity'],
#  ['Jeans', 'Sweaters', 'Active', 'Intimates'],
#  ['Tops & Tees', 'Sleep & Lounge', 'Tops & Tees'],
#  ['Tops & Tees', 'Intimates'],
#  ['Sweaters', 'Tops & Tees'],
#  ['Sweaters', 'Fashion Hoodies & Sweatshirts'],
#  ['Socks & Hosiery',
#   'Jeans',
#   'Plus',
#   'Plus',
#   'Jumpsuits & Rompers',
#   'Socks & Hosiery'],
#  ['Plus'],
#  ['Jeans',
#   'Blazers & Jackets',
#   'Blazers & Jackets',
#   'Fashion Hoodies & Sweatshirts',
#   'Swim',
#   'Suits',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Sweaters', 'Fashion Hoodies & Sweatshirts'],
#  ['Maternity', 'Fashion Hoodies & Sweatshirts'],
#  ['Dresses', 'Accessories', 'Swim', 'Jeans', 'Jumpsuits & Rompers'],
#  ['Shorts'],
#  ['Maternity', 'Skirts'],
#  ['Active', 'Plus', 'Socks & Hosiery'],
#  ['Swim', 'Maternity', 'Shorts', 'Swim', 'Intimates', 'Swim'],
#  ['Swim', 'Intimates'],
#  ['Outerwear & Coats', 'Leggings'],
#  ['Jeans', 'Jeans', 'Dresses', 'Intimates'],
#  ['Dresses', 'Leggings', 'Jeans', 'Intimates', 'Active', 'Intimates'],
#  ['Jeans', 'Swim', 'Fashion Hoodies & Sweatshirts', 'Dresses'],
#  ['Pants & Capris',
#   'Outerwear & Coats',
#   'Jeans',
#   'Sleep & Lounge',
#   'Sleep & Lounge',
#   'Intimates'],
#  ['Leggings', 'Intimates'],
#  ['Outerwear & Coats', 'Skirts', 'Plus'],
#  ['Pants & Capris', 'Pants & Capris'],
#  ['Intimates', 'Accessories', 'Socks & Hosiery'],
#  ['Shorts', 'Swim', 'Intimates'],
#  ['Sleep & Lounge', 'Skirts', 'Socks & Hosiery'],
#  ['Socks & Hosiery', 'Fashion Hoodies & Sweatshirts', 'Maternity'],
#  ['Intimates', 'Jumpsuits & Rompers'],
#  ['Pants & Capris', 'Plus'],
#  ['Shorts', 'Intimates'],
#  ['Sweaters', 'Intimates', 'Swim', 'Skirts'],
#  ['Sweaters', 'Sweaters'],
#  ['Blazers & Jackets',
#   'Maternity',
#   'Blazers & Jackets',
#   'Intimates',
#   'Active'],
#  ['Outerwear & Coats', 'Socks & Hosiery'],
#  ['Socks & Hosiery', 'Socks & Hosiery'],
#  ['Fashion Hoodies & Sweatshirts', 'Outerwear & Coats'],
#  ['Jeans', 'Swim', 'Dresses', 'Fashion Hoodies & Sweatshirts'],
#  ['Sleep & Lounge', 'Dresses', 'Intimates', 'Plus', 'Blazers & Jackets'],
#  ['Maternity', 'Plus', 'Tops & Tees', 'Active'],
#  ['Swim', 'Pants & Capris', 'Socks & Hosiery'],
#  ['Maternity', 'Skirts'],
#  ['Intimates', 'Intimates'],
#  ['Intimates', 'Tops & Tees', 'Blazers & Jackets', 'Intimates'],
#  ['Dresses', 'Tops & Tees'],
#  ['Sleep & Lounge', 'Suits'],
#  ['Outerwear & Coats', 'Jeans'],
#  ['Sweaters', 'Sleep & Lounge'],
#  ['Pants & Capris'],
#  ['Shorts', 'Intimates', 'Active', 'Blazers & Jackets', 'Tops & Tees'],
#  ['Pants & Capris', 'Intimates', 'Sleep & Lounge', 'Swim', 'Pants & Capris'],
#  ['Tops & Tees', 'Fashion Hoodies & Sweatshirts'],
#  ['Active', 'Sleep & Lounge', 'Tops & Tees'],
#  ['Maternity'],
#  ['Plus', 'Plus', 'Swim'],
#  ['Plus'],
#  ['Sweaters', 'Tops & Tees'],
#  ['Active', 'Blazers & Jackets'],
#  ['Plus', 'Leggings', 'Intimates'],
#  ['Accessories', 'Sleep & Lounge', 'Swim', 'Swim'],
#  ['Shorts', 'Dresses', 'Tops & Tees'],
#  ['Maternity', 'Sleep & Lounge'],
#  ['Pants & Capris'],
#  ['Shorts', 'Blazers & Jackets', 'Leggings', 'Dresses'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Accessories',
#   'Tops & Tees',
#   'Blazers & Jackets'],
#  ['Pants & Capris', 'Socks & Hosiery'],
#  ['Intimates', 'Intimates'],
#  ['Leggings'],
#  ['Tops & Tees', 'Accessories'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Fashion Hoodies & Sweatshirts',
#   'Sleep & Lounge',
#   'Pants & Capris'],
#  ['Fashion Hoodies & Sweatshirts', 'Active'],
#  ['Fashion Hoodies & Sweatshirts', 'Socks & Hosiery'],
#  ['Shorts', 'Maternity'],
#  ['Leggings', 'Swim', 'Active', 'Blazers & Jackets', 'Sleep & Lounge'],
#  ['Accessories', 'Leggings', 'Sweaters', 'Swim'],
#  ['Maternity', 'Intimates', 'Skirts', 'Tops & Tees'],
#  ['Intimates', 'Sleep & Lounge', 'Swim'],
#  ['Tops & Tees',
#   'Blazers & Jackets',
#   'Accessories',
#   'Fashion Hoodies & Sweatshirts',
#   'Fashion Hoodies & Sweatshirts',
#   'Maternity',
#   'Plus'],
#  ['Intimates'],
#  ['Sleep & Lounge', 'Accessories', 'Dresses'],
#  ['Tops & Tees'],
#  ['Intimates', 'Maternity'],
#  ['Dresses', 'Tops & Tees', 'Plus', 'Outerwear & Coats', 'Swim', 'Intimates'],
#  ['Maternity', 'Fashion Hoodies & Sweatshirts', 'Sleep & Lounge'],
#  ['Swim',
#   'Sleep & Lounge',
#   'Clothing Sets',
#   'Socks & Hosiery',
#   'Swim',
#   'Plus',
#   'Suits'],
#  ['Sleep & Lounge', 'Active', 'Intimates'],
#  ['Swim', 'Fashion Hoodies & Sweatshirts', 'Maternity', 'Dresses'],
#  ['Intimates', 'Sleep & Lounge', 'Tops & Tees', 'Maternity', 'Intimates'],
#  ['Intimates', 'Jeans', 'Intimates', 'Intimates'],
#  ['Socks & Hosiery', 'Shorts', 'Accessories'],
#  ['Blazers & Jackets'],
#  ['Plus', 'Maternity', 'Socks & Hosiery', 'Plus'],
#  ['Sleep & Lounge', 'Jeans'],
#  ['Jeans', 'Jeans', 'Outerwear & Coats'],
#  ['Plus'],
#  ['Active', 'Skirts', 'Tops & Tees'],
#  ['Intimates', 'Tops & Tees', 'Suits', 'Tops & Tees', 'Swim', 'Intimates'],
#  ['Dresses', 'Maternity', 'Maternity', 'Pants & Capris'],
#  ['Pants & Capris', 'Outerwear & Coats', 'Leggings'],
#  ['Dresses', 'Swim', 'Dresses', 'Skirts', 'Pants & Capris'],
#  ['Sleep & Lounge', 'Jumpsuits & Rompers'],
#  ['Sweaters', 'Pants & Capris'],
#  ['Intimates', 'Intimates'],
#  ['Suits', 'Pants & Capris', 'Intimates'],
#  ['Intimates', 'Blazers & Jackets', 'Swim', 'Accessories'],
#  ['Plus', 'Plus'],
#  ['Maternity', 'Socks & Hosiery', 'Sweaters'],
#  ['Intimates', 'Maternity'],
#  ['Skirts',
#   'Active',
#   'Sweaters',
#   'Accessories',
#   'Intimates',
#   'Swim',
#   'Intimates'],
#  ['Blazers & Jackets'],
#  ['Socks & Hosiery', 'Sweaters', 'Maternity'],
#  ['Fashion Hoodies & Sweatshirts', 'Skirts'],
#  ['Blazers & Jackets'],
#  ['Pants & Capris', 'Outerwear & Coats'],
#  ['Intimates', 'Intimates'],
#  ['Accessories',
#   'Sweaters',
#   'Fashion Hoodies & Sweatshirts',
#   'Blazers & Jackets',
#   'Intimates',
#   'Dresses'],
#  ['Shorts', 'Fashion Hoodies & Sweatshirts', 'Jumpsuits & Rompers'],
#  ['Jeans',
#   'Jumpsuits & Rompers',
#   'Leggings',
#   'Sleep & Lounge',
#   'Pants & Capris',
#   'Jeans'],
#  ['Intimates', 'Maternity', 'Sweaters'],
#  ['Active'],
#  ['Swim', 'Maternity'],
#  ['Tops & Tees'],
#  ['Dresses', 'Plus', 'Sleep & Lounge'],
#  ['Fashion Hoodies & Sweatshirts', 'Sleep & Lounge'],
#  ['Leggings', 'Sleep & Lounge'],
#  ['Dresses', 'Maternity', 'Sleep & Lounge', 'Fashion Hoodies & Sweatshirts'],
#  ['Intimates', 'Fashion Hoodies & Sweatshirts', 'Skirts', 'Intimates'],
#  ['Pants & Capris', 'Intimates', 'Socks & Hosiery', 'Maternity'],
#  ['Sweaters', 'Blazers & Jackets', 'Maternity'],
#  ['Leggings', 'Intimates', 'Maternity', 'Dresses'],
#  ['Accessories', 'Socks & Hosiery', 'Sleep & Lounge'],
#  ['Tops & Tees', 'Outerwear & Coats', 'Blazers & Jackets'],
#  ['Pants & Capris', 'Plus'],
#  ['Leggings', 'Maternity', 'Blazers & Jackets', 'Active', 'Intimates'],
#  ['Outerwear & Coats', 'Shorts'],
#  ['Swim', 'Maternity'],
#  ['Jeans', 'Socks & Hosiery'],
#  ['Intimates', 'Jumpsuits & Rompers'],
#  ['Socks & Hosiery', 'Jeans'],
#  ['Accessories',
#   'Active',
#   'Intimates',
#   'Tops & Tees',
#   'Tops & Tees',
#   'Pants & Capris'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Plus',
#   'Dresses',
#   'Accessories',
#   'Sweaters',
#   'Active'],
#  ['Intimates', 'Maternity'],
#  ['Fashion Hoodies & Sweatshirts', 'Accessories'],
#  ['Sweaters',
#   'Sleep & Lounge',
#   'Blazers & Jackets',
#   'Jeans',
#   'Socks & Hosiery',
#   'Accessories'],
#  ['Leggings',
#   'Fashion Hoodies & Sweatshirts',
#   'Pants & Capris',
#   'Tops & Tees',
#   'Intimates',
#   'Socks & Hosiery',
#   'Jeans',
#   'Maternity'],
#  ['Sleep & Lounge',
#   'Blazers & Jackets',
#   'Dresses',
#   'Tops & Tees',
#   'Suits',
#   'Outerwear & Coats'],
#  ['Active', 'Pants & Capris', 'Intimates', 'Leggings'],
#  ['Maternity', 'Accessories', 'Tops & Tees', 'Pants & Capris', 'Maternity'],
#  ['Pants & Capris',
#   'Shorts',
#   'Outerwear & Coats',
#   'Fashion Hoodies & Sweatshirts',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Pants & Capris',
#   'Fashion Hoodies & Sweatshirts',
#   'Swim',
#   'Outerwear & Coats'],
#  ['Socks & Hosiery', 'Swim', 'Sweaters', 'Intimates'],
#  ['Active', 'Jeans', 'Sleep & Lounge'],
#  ['Shorts', 'Dresses', 'Swim', 'Intimates', 'Active'],
#  ['Sleep & Lounge', 'Dresses', 'Shorts', 'Sweaters', 'Blazers & Jackets'],
#  ['Jeans'],
#  ['Pants & Capris', 'Accessories'],
#  ['Pants & Capris', 'Intimates', 'Active', 'Jeans'],
#  ['Intimates', 'Maternity'],
#  ['Skirts', 'Sleep & Lounge'],
#  ['Jeans', 'Intimates'],
#  ['Swim', 'Jumpsuits & Rompers'],
#  ['Pants & Capris', 'Intimates'],
#  ['Maternity', 'Intimates'],
#  ['Skirts', 'Intimates', 'Maternity', 'Maternity'],
#  ['Active',
#   'Fashion Hoodies & Sweatshirts',
#   'Blazers & Jackets',
#   'Suits',
#   'Socks & Hosiery'],
#  ['Fashion Hoodies & Sweatshirts', 'Outerwear & Coats'],
#  ['Tops & Tees', 'Intimates'],
#  ['Maternity', 'Jeans', 'Intimates'],
#  ['Swim', 'Outerwear & Coats'],
#  ['Socks & Hosiery', 'Accessories', 'Jeans', 'Intimates', 'Intimates'],
#  ['Intimates', 'Outerwear & Coats'],
#  ['Sweaters', 'Fashion Hoodies & Sweatshirts'],
#  ['Maternity', 'Swim', 'Socks & Hosiery', 'Sweaters'],
#  ['Tops & Tees', 'Active', 'Plus', 'Maternity', 'Tops & Tees'],
#  ['Intimates'],
#  ['Dresses', 'Shorts', 'Jumpsuits & Rompers'],
#  ['Fashion Hoodies & Sweatshirts', 'Dresses'],
#  ['Leggings', 'Outerwear & Coats', 'Swim'],
#  ['Swim', 'Blazers & Jackets', 'Accessories', 'Maternity'],
#  ['Outerwear & Coats',
#   'Tops & Tees',
#   'Socks & Hosiery',
#   'Dresses',
#   'Intimates',
#   'Accessories',
#   'Blazers & Jackets'],
#  ['Jeans'],
#  ['Dresses', 'Jeans'],
#  ['Plus', 'Fashion Hoodies & Sweatshirts'],
#  ['Active', 'Sleep & Lounge', 'Sweaters', 'Intimates', 'Tops & Tees'],
#  ['Suits', 'Intimates'],
#  ['Active', 'Maternity'],
#  ['Skirts', 'Jeans', 'Accessories', 'Jeans', 'Jeans'],
#  ['Outerwear & Coats', 'Intimates'],
#  ['Swim', 'Clothing Sets'],
#  ['Blazers & Jackets',
#   'Sleep & Lounge',
#   'Swim',
#   'Blazers & Jackets',
#   'Jumpsuits & Rompers'],
#  ['Fashion Hoodies & Sweatshirts', 'Blazers & Jackets'],
#  ['Plus', 'Tops & Tees', 'Jeans'],
#  ['Skirts',
#   'Outerwear & Coats',
#   'Outerwear & Coats',
#   'Shorts',
#   'Outerwear & Coats',
#   'Leggings',
#   'Sweaters'],
#  ['Maternity', 'Jeans', 'Active', 'Outerwear & Coats'],
#  ['Dresses'],
#  ['Intimates', 'Maternity'],
#  ['Intimates'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Intimates',
#   'Swim',
#   'Maternity',
#   'Maternity'],
#  ['Maternity', 'Intimates'],
#  ['Sleep & Lounge',
#   'Skirts',
#   'Shorts',
#   'Fashion Hoodies & Sweatshirts',
#   'Shorts'],
#  ['Swim',
#   'Intimates',
#   'Outerwear & Coats',
#   'Dresses',
#   'Intimates',
#   'Swim',
#   'Jeans'],
#  ['Accessories', 'Sweaters', 'Swim'],
#  ['Intimates', 'Intimates'],
#  ['Tops & Tees',
#   'Intimates',
#   'Maternity',
#   'Intimates',
#   'Intimates',
#   'Active',
#   'Accessories',
#   'Socks & Hosiery'],
#  ['Jeans', 'Shorts', 'Jumpsuits & Rompers', 'Sleep & Lounge', 'Accessories'],
#  ['Sweaters', 'Sleep & Lounge', 'Maternity'],
#  ['Pants & Capris', 'Sleep & Lounge'],
#  ['Sleep & Lounge',
#   'Pants & Capris',
#   'Pants & Capris',
#   'Tops & Tees',
#   'Maternity'],
#  ['Socks & Hosiery',
#   'Active',
#   'Accessories',
#   'Jumpsuits & Rompers',
#   'Jumpsuits & Rompers'],
#  ['Active', 'Intimates', 'Sweaters'],
#  ['Intimates',
#   'Outerwear & Coats',
#   'Tops & Tees',
#   'Outerwear & Coats',
#   'Sweaters'],
#  ['Intimates', 'Active', 'Swim', 'Accessories'],
#  ['Intimates', 'Jeans', 'Maternity', 'Intimates', 'Sweaters'],
#  ['Accessories', 'Blazers & Jackets', 'Maternity'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Dresses',
#   'Shorts',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Tops & Tees', 'Dresses', 'Plus', 'Outerwear & Coats', 'Sweaters'],
#  ['Outerwear & Coats', 'Sweaters'],
#  ['Plus', 'Outerwear & Coats', 'Intimates'],
#  ['Pants & Capris', 'Fashion Hoodies & Sweatshirts', 'Maternity'],
#  ['Intimates', 'Jeans'],
#  ['Outerwear & Coats', 'Active'],
#  ['Intimates', 'Active', 'Plus'],
#  ['Pants & Capris', 'Blazers & Jackets'],
#  ['Socks & Hosiery'],
#  ['Dresses', 'Intimates', 'Plus'],
#  ['Leggings', 'Tops & Tees', 'Accessories'],
#  ['Shorts'],
#  ['Intimates', 'Swim', 'Maternity'],
#  ['Intimates', 'Accessories', 'Shorts', 'Jeans'],
#  ['Outerwear & Coats', 'Outerwear & Coats'],
#  ['Skirts', 'Leggings', 'Socks & Hosiery'],
#  ['Jeans', 'Jeans'],
#  ['Jeans', 'Sweaters', 'Blazers & Jackets'],
#  ['Jeans', 'Maternity', 'Intimates'],
#  ['Jeans', 'Plus', 'Shorts', 'Intimates', 'Jeans'],
#  ['Plus'],
#  ['Intimates', 'Sweaters', 'Leggings', 'Swim', 'Dresses'],
#  ['Intimates', 'Sweaters', 'Swim', 'Dresses', 'Leggings'],
#  ['Leggings', 'Intimates', 'Dresses', 'Intimates'],
#  ['Jeans', 'Tops & Tees', 'Outerwear & Coats'],
#  ['Skirts', 'Maternity'],
#  ['Sweaters',
#   'Outerwear & Coats',
#   'Tops & Tees',
#   'Tops & Tees',
#   'Intimates',
#   'Maternity',
#   'Suits'],
#  ['Sweaters', 'Jeans', 'Dresses'],
#  ['Sleep & Lounge', 'Shorts'],
#  ['Plus', 'Tops & Tees', 'Accessories'],
#  ['Accessories', 'Maternity', 'Fashion Hoodies & Sweatshirts'],
#  ['Sweaters', 'Intimates', 'Blazers & Jackets'],
#  ['Outerwear & Coats',
#   'Sleep & Lounge',
#   'Fashion Hoodies & Sweatshirts',
#   'Socks & Hosiery'],
#  ['Socks & Hosiery', 'Leggings'],
#  ['Plus', 'Active', 'Dresses', 'Tops & Tees', 'Shorts'],
#  ['Accessories', 'Intimates', 'Intimates'],
#  ['Intimates', 'Blazers & Jackets'],
#  ['Fashion Hoodies & Sweatshirts', 'Sleep & Lounge', 'Active'],
#  ['Dresses', 'Dresses', 'Fashion Hoodies & Sweatshirts'],
#  ['Jeans'],
#  ['Intimates', 'Sleep & Lounge', 'Intimates'],
#  ['Maternity', 'Shorts', 'Blazers & Jackets', 'Maternity'],
#  ['Active',
#   'Fashion Hoodies & Sweatshirts',
#   'Intimates',
#   'Suits',
#   'Leggings',
#   'Pants & Capris'],
#  ['Dresses', 'Dresses', 'Swim'],
#  ['Fashion Hoodies & Sweatshirts', 'Jeans', 'Tops & Tees'],
#  ['Sweaters', 'Swim', 'Swim'],
#  ['Sweaters', 'Shorts', 'Fashion Hoodies & Sweatshirts', 'Shorts'],
#  ['Jeans', 'Accessories', 'Maternity'],
#  ['Swim', 'Intimates', 'Maternity'],
#  ['Jeans'],
#  ['Tops & Tees', 'Maternity', 'Pants & Capris', 'Intimates', 'Accessories'],
#  ['Active', 'Jumpsuits & Rompers', 'Sleep & Lounge'],
#  ['Fashion Hoodies & Sweatshirts', 'Plus', 'Skirts'],
#  ['Fashion Hoodies & Sweatshirts'],
#  ['Shorts', 'Leggings', 'Swim', 'Jeans'],
#  ['Maternity', 'Sleep & Lounge', 'Shorts'],
#  ['Dresses', 'Sleep & Lounge', 'Sweaters', 'Swim'],
#  ['Tops & Tees', 'Plus', 'Outerwear & Coats'],
#  ['Shorts',
#   'Dresses',
#   'Intimates',
#   'Intimates',
#   'Intimates',
#   'Intimates',
#   'Sweaters'],
#  ['Leggings', 'Pants & Capris', 'Dresses', 'Jeans'],
#  ['Intimates'],
#  ['Skirts', 'Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Plus', 'Maternity'],
#  ['Sleep & Lounge'],
#  ['Fashion Hoodies & Sweatshirts', 'Intimates', 'Intimates', 'Dresses'],
#  ['Tops & Tees', 'Tops & Tees'],
#  ['Swim', 'Socks & Hosiery'],
#  ['Intimates', 'Jeans'],
#  ['Maternity', 'Leggings', 'Sweaters'],
#  ['Active', 'Swim', 'Maternity'],
#  ['Swim',
#   'Maternity',
#   'Accessories',
#   'Active',
#   'Blazers & Jackets',
#   'Pants & Capris'],
#  ['Active'],
#  ['Shorts', 'Intimates', 'Intimates'],
#  ['Intimates', 'Leggings', 'Intimates'],
#  ['Tops & Tees',
#   'Outerwear & Coats',
#   'Fashion Hoodies & Sweatshirts',
#   'Tops & Tees',
#   'Shorts',
#   'Tops & Tees'],
#  ['Sleep & Lounge', 'Shorts'],
#  ['Intimates', 'Accessories', 'Shorts', 'Swim', 'Sleep & Lounge', 'Swim'],
#  ['Intimates',
#   'Active',
#   'Plus',
#   'Fashion Hoodies & Sweatshirts',
#   'Blazers & Jackets'],
#  ['Blazers & Jackets',
#   'Jeans',
#   'Swim',
#   'Pants & Capris',
#   'Tops & Tees',
#   'Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Intimates',
#   'Jeans'],
#  ['Blazers & Jackets', 'Blazers & Jackets'],
#  ['Blazers & Jackets', 'Intimates'],
#  ['Active', 'Suits', 'Blazers & Jackets'],
#  ['Jeans', 'Intimates', 'Dresses', 'Suits', 'Blazers & Jackets'],
#  ['Intimates', 'Leggings', 'Fashion Hoodies & Sweatshirts', 'Accessories'],
#  ['Fashion Hoodies & Sweatshirts', 'Fashion Hoodies & Sweatshirts'],
#  ['Sleep & Lounge',
#   'Maternity',
#   'Plus',
#   'Socks & Hosiery',
#   'Fashion Hoodies & Sweatshirts',
#   'Swim',
#   'Suits',
#   'Intimates'],
#  ['Blazers & Jackets', 'Socks & Hosiery'],
#  ['Sleep & Lounge',
#   'Shorts',
#   'Accessories',
#   'Sleep & Lounge',
#   'Tops & Tees',
#   'Sweaters'],
#  ['Jeans', 'Accessories', 'Maternity', 'Accessories'],
#  ['Blazers & Jackets', 'Active', 'Skirts'],
#  ['Outerwear & Coats', 'Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Accessories',
#   'Dresses',
#   'Active',
#   'Blazers & Jackets',
#   'Leggings',
#   'Intimates',
#   'Jeans'],
#  ['Swim', 'Jumpsuits & Rompers'],
#  ['Plus'],
#  ['Dresses', 'Outerwear & Coats'],
#  ['Maternity', 'Maternity', 'Active'],
#  ['Intimates', 'Tops & Tees'],
#  ['Intimates', 'Outerwear & Coats', 'Sleep & Lounge'],
#  ['Intimates', 'Plus', 'Swim', 'Plus'],
#  ['Sweaters', 'Intimates'],
#  ['Dresses'],
#  ['Intimates',
#   'Jeans',
#   'Plus',
#   'Fashion Hoodies & Sweatshirts',
#   'Intimates',
#   'Sweaters'],
#  ['Swim', 'Tops & Tees', 'Active', 'Fashion Hoodies & Sweatshirts'],
#  ['Intimates', 'Sweaters', 'Tops & Tees', 'Dresses'],
#  ['Shorts', 'Swim'],
#  ['Plus', 'Accessories'],
#  ['Swim', 'Sleep & Lounge', 'Shorts'],
#  ['Sweaters', 'Shorts'],
#  ['Intimates', 'Outerwear & Coats', 'Active'],
#  ['Sleep & Lounge',
#   'Accessories',
#   'Intimates',
#   'Dresses',
#   'Shorts',
#   'Maternity',
#   'Active'],
#  ['Tops & Tees'],
#  ['Maternity',
#   'Shorts',
#   'Intimates',
#   'Dresses',
#   'Active',
#   'Pants & Capris',
#   'Accessories'],
#  ['Dresses', 'Sleep & Lounge'],
#  ['Suits', 'Tops & Tees'],
#  ['Plus', 'Pants & Capris', 'Accessories', 'Tops & Tees'],
#  ['Jeans'],
#  ['Pants & Capris', 'Plus', 'Intimates'],
#  ['Swim', 'Swim'],
#  ['Socks & Hosiery',
#   'Sleep & Lounge',
#   'Leggings',
#   'Swim',
#   'Leggings',
#   'Intimates'],
#  ['Shorts', 'Skirts', 'Plus', 'Tops & Tees'],
#  ['Blazers & Jackets', 'Sleep & Lounge'],
#  ['Swim', 'Active', 'Intimates', 'Socks & Hosiery', 'Dresses', 'Sweaters'],
#  ['Active'],
#  ['Dresses', 'Fashion Hoodies & Sweatshirts'],
#  ['Tops & Tees', 'Active'],
#  ['Intimates', 'Active'],
#  ['Intimates', 'Intimates'],
#  ['Sleep & Lounge', 'Socks & Hosiery', 'Dresses', 'Intimates'],
#  ['Jeans', 'Fashion Hoodies & Sweatshirts'],
#  ['Plus', 'Outerwear & Coats', 'Skirts'],
#  ['Active', 'Intimates', 'Socks & Hosiery', 'Maternity', 'Socks & Hosiery'],
#  ['Sweaters', 'Shorts', 'Swim'],
#  ['Active', 'Accessories', 'Jeans', 'Jumpsuits & Rompers', 'Accessories'],
#  ['Dresses', 'Dresses'],
#  ['Suits', 'Intimates', 'Clothing Sets'],
#  ['Fashion Hoodies & Sweatshirts'],
#  ['Jeans', 'Tops & Tees', 'Sweaters'],
#  ['Plus', 'Sweaters', 'Swim'],
#  ['Maternity', 'Plus', 'Pants & Capris'],
#  ['Dresses',
#   'Fashion Hoodies & Sweatshirts',
#   'Shorts',
#   'Outerwear & Coats',
#   'Intimates'],
#  ['Sweaters', 'Swim', 'Tops & Tees'],
#  ['Leggings', 'Leggings'],
#  ['Pants & Capris', 'Pants & Capris', 'Intimates'],
#  ['Intimates', 'Sleep & Lounge'],
#  ['Plus', 'Swim', 'Intimates'],
#  ['Maternity', 'Tops & Tees', 'Tops & Tees'],
#  ['Maternity'],
#  ['Intimates', 'Intimates', 'Jumpsuits & Rompers', 'Maternity', 'Intimates'],
#  ['Swim', 'Fashion Hoodies & Sweatshirts', 'Swim'],
#  ['Intimates', 'Blazers & Jackets', 'Tops & Tees'],
#  ['Intimates', 'Fashion Hoodies & Sweatshirts'],
#  ['Intimates',
#   'Jeans',
#   'Fashion Hoodies & Sweatshirts',
#   'Active',
#   'Intimates',
#   'Dresses',
#   'Jumpsuits & Rompers'],
#  ['Intimates'],
#  ['Intimates'],
#  ['Intimates', 'Plus', 'Intimates', 'Skirts', 'Tops & Tees', 'Accessories'],
#  ['Leggings', 'Dresses', 'Swim'],
#  ['Jeans', 'Fashion Hoodies & Sweatshirts', 'Plus'],
#  ['Intimates', 'Intimates', 'Sweaters'],
#  ['Socks & Hosiery'],
#  ['Dresses', 'Outerwear & Coats', 'Accessories'],
#  ['Outerwear & Coats', 'Tops & Tees', 'Skirts', 'Leggings', 'Pants & Capris'],
#  ['Shorts'],
#  ['Shorts', 'Tops & Tees', 'Blazers & Jackets', 'Active'],
#  ['Shorts',
#   'Intimates',
#   'Intimates',
#   'Sweaters',
#   'Intimates',
#   'Shorts',
#   'Intimates'],
#  ['Socks & Hosiery', 'Plus', 'Shorts', 'Plus'],
#  ['Shorts', 'Swim'],
#  ['Accessories', 'Maternity', 'Accessories', 'Socks & Hosiery', 'Intimates'],
#  ['Pants & Capris', 'Outerwear & Coats'],
#  ['Intimates', 'Suits', 'Jeans'],
#  ['Sweaters', 'Shorts'],
#  ['Leggings', 'Intimates', 'Outerwear & Coats'],
#  ['Plus', 'Shorts', 'Sweaters'],
#  ['Skirts', 'Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Outerwear & Coats', 'Sweaters'],
#  ['Jeans', 'Accessories', 'Dresses', 'Jeans'],
#  ['Tops & Tees', 'Fashion Hoodies & Sweatshirts', 'Accessories', 'Dresses'],
#  ['Leggings', 'Jumpsuits & Rompers'],
#  ['Intimates', 'Socks & Hosiery'],
#  ['Shorts', 'Swim'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Active',
#   'Jeans',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Active', 'Tops & Tees'],
#  ['Maternity'],
#  ['Blazers & Jackets', 'Swim'],
#  ['Dresses', 'Shorts'],
#  ['Swim', 'Shorts'],
#  ['Leggings', 'Jeans', 'Blazers & Jackets', 'Shorts'],
#  ['Swim', 'Shorts'],
#  ['Tops & Tees',
#   'Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Leggings',
#   'Outerwear & Coats',
#   'Plus'],
#  ['Socks & Hosiery', 'Socks & Hosiery'],
#  ['Sleep & Lounge', 'Maternity', 'Sleep & Lounge'],
#  ['Socks & Hosiery', 'Leggings', 'Intimates'],
#  ['Swim', 'Tops & Tees'],
#  ['Maternity', 'Shorts', 'Shorts'],
#  ['Intimates', 'Intimates', 'Outerwear & Coats'],
#  ['Swim', 'Pants & Capris', 'Plus'],
#  ['Accessories', 'Leggings'],
#  ['Intimates', 'Sleep & Lounge', 'Socks & Hosiery', 'Maternity'],
#  ['Pants & Capris'],
#  ['Intimates', 'Maternity', 'Intimates'],
#  ['Tops & Tees', 'Plus'],
#  ['Socks & Hosiery',
#   'Outerwear & Coats',
#   'Blazers & Jackets',
#   'Blazers & Jackets'],
#  ['Active', 'Outerwear & Coats'],
#  ['Outerwear & Coats', 'Jeans', 'Jeans'],
#  ['Socks & Hosiery', 'Socks & Hosiery', 'Intimates'],
#  ['Socks & Hosiery', 'Jeans'],
#  ['Socks & Hosiery'],
#  ['Outerwear & Coats', 'Active', 'Pants & Capris', 'Pants & Capris'],
#  ['Dresses', 'Plus'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Suits',
#   'Jumpsuits & Rompers',
#   'Maternity',
#   'Outerwear & Coats'],
#  ['Skirts', 'Sweaters', 'Jeans', 'Fashion Hoodies & Sweatshirts'],
#  ['Intimates', 'Skirts', 'Intimates', 'Leggings'],
#  ['Blazers & Jackets', 'Sweaters', 'Swim'],
#  ['Plus', 'Plus', 'Accessories', 'Jeans', 'Intimates'],
#  ['Maternity',
#   'Plus',
#   'Plus',
#   'Pants & Capris',
#   'Blazers & Jackets',
#   'Sweaters',
#   'Accessories'],
#  ['Shorts'],
#  ['Leggings', 'Sweaters'],
#  ['Shorts', 'Swim'],
#  ['Outerwear & Coats', 'Maternity', 'Socks & Hosiery'],
#  ['Jeans'],
#  ['Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Sleep & Lounge', 'Tops & Tees', 'Jeans'],
#  ['Leggings'],
#  ['Intimates'],
#  ['Jeans', 'Shorts'],
#  ['Dresses', 'Intimates', 'Fashion Hoodies & Sweatshirts'],
#  ['Intimates', 'Accessories', 'Blazers & Jackets', 'Socks & Hosiery', 'Jeans'],
#  ['Active', 'Dresses'],
#  ['Intimates', 'Intimates'],
#  ['Intimates', 'Intimates'],
#  ['Intimates'],
#  ['Plus'],
#  ['Fashion Hoodies & Sweatshirts', 'Skirts'],
#  ['Blazers & Jackets', 'Active', 'Sweaters'],
#  ['Dresses', 'Shorts', 'Plus'],
#  ['Jeans', 'Tops & Tees', 'Jeans'],
#  ['Sleep & Lounge', 'Outerwear & Coats', 'Active', 'Tops & Tees'],
#  ['Active'],
#  ['Skirts',
#   'Tops & Tees',
#   'Sleep & Lounge',
#   'Socks & Hosiery',
#   'Maternity',
#   'Skirts'],
#  ['Intimates', 'Active'],
#  ['Accessories', 'Shorts', 'Intimates'],
#  ['Intimates', 'Socks & Hosiery', 'Swim'],
#  ['Pants & Capris', 'Active'],
#  ['Outerwear & Coats', 'Accessories', 'Sleep & Lounge', 'Swim'],
#  ['Fashion Hoodies & Sweatshirts', 'Suits'],
#  ['Dresses',
#   'Outerwear & Coats',
#   'Accessories',
#   'Sleep & Lounge',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Sleep & Lounge', 'Fashion Hoodies & Sweatshirts', 'Maternity'],
#  ['Suits', 'Outerwear & Coats', 'Maternity', 'Intimates'],
#  ['Pants & Capris', 'Tops & Tees', 'Shorts', 'Sleep & Lounge'],
#  ['Intimates', 'Skirts', 'Maternity', 'Dresses'],
#  ['Plus'],
#  ['Leggings', 'Dresses', 'Outerwear & Coats', 'Plus', 'Active'],
#  ['Dresses', 'Socks & Hosiery', 'Plus'],
#  ['Fashion Hoodies & Sweatshirts'],
#  ['Active', 'Sweaters'],
#  ['Skirts', 'Socks & Hosiery', 'Fashion Hoodies & Sweatshirts'],
#  ['Dresses', 'Sleep & Lounge', 'Dresses'],
#  ['Active', 'Maternity', 'Shorts'],
#  ['Sweaters', 'Plus'],
#  ['Leggings', 'Outerwear & Coats', 'Socks & Hosiery', 'Active'],
#  ['Intimates', 'Swim', 'Intimates'],
#  ['Plus', 'Intimates', 'Swim'],
#  ['Swim', 'Pants & Capris'],
#  ['Accessories', 'Leggings', 'Active'],
#  ['Leggings', 'Leggings', 'Fashion Hoodies & Sweatshirts'],
#  ['Fashion Hoodies & Sweatshirts', 'Outerwear & Coats'],
#  ['Dresses', 'Intimates', 'Maternity'],
#  ['Outerwear & Coats', 'Sleep & Lounge', 'Fashion Hoodies & Sweatshirts'],
#  ['Jeans', 'Intimates', 'Accessories', 'Sleep & Lounge', 'Leggings'],
#  ['Accessories', 'Sleep & Lounge', 'Sleep & Lounge', 'Dresses'],
#  ['Shorts'],
#  ['Swim', 'Fashion Hoodies & Sweatshirts'],
#  ['Pants & Capris',
#   'Blazers & Jackets',
#   'Sleep & Lounge',
#   'Intimates',
#   'Dresses',
#   'Pants & Capris'],
#  ['Intimates', 'Dresses', 'Socks & Hosiery', 'Dresses'],
#  ['Swim', 'Intimates'],
#  ['Jeans',
#   'Socks & Hosiery',
#   'Jeans',
#   'Socks & Hosiery',
#   'Tops & Tees',
#   'Dresses'],
#  ['Dresses', 'Tops & Tees', 'Sleep & Lounge'],
#  ['Blazers & Jackets', 'Dresses', 'Dresses'],
#  ['Outerwear & Coats', 'Dresses'],
#  ['Fashion Hoodies & Sweatshirts', 'Sweaters', 'Shorts', 'Sweaters', 'Shorts'],
#  ['Intimates', 'Swim', 'Blazers & Jackets'],
#  ['Intimates', 'Accessories', 'Tops & Tees', 'Sleep & Lounge', 'Dresses'],
#  ['Dresses', 'Tops & Tees', 'Pants & Capris', 'Jeans', 'Active'],
#  ['Sleep & Lounge', 'Fashion Hoodies & Sweatshirts', 'Shorts'],
#  ['Skirts', 'Outerwear & Coats', 'Maternity'],
#  ['Blazers & Jackets', 'Jeans', 'Intimates'],
#  ['Plus', 'Dresses', 'Tops & Tees', 'Maternity', 'Plus'],
#  ['Sweaters', 'Tops & Tees'],
#  ['Dresses', 'Jeans', 'Dresses', 'Accessories'],
#  ['Blazers & Jackets', 'Jeans', 'Jeans'],
#  ['Jeans', 'Swim', 'Fashion Hoodies & Sweatshirts', 'Maternity'],
#  ['Shorts', 'Intimates', 'Accessories', 'Suits'],
#  ['Shorts', 'Fashion Hoodies & Sweatshirts', 'Intimates', 'Blazers & Jackets'],
#  ['Accessories', 'Fashion Hoodies & Sweatshirts', 'Intimates'],
#  ['Skirts', 'Accessories', 'Shorts', 'Sleep & Lounge'],
#  ['Sweaters', 'Fashion Hoodies & Sweatshirts', 'Plus'],
#  ['Skirts', 'Maternity', 'Jeans', 'Sweaters'],
#  ['Maternity', 'Shorts'],
#  ['Dresses', 'Shorts'],
#  ['Sleep & Lounge', 'Jumpsuits & Rompers'],
#  ['Intimates', 'Blazers & Jackets'],
#  ['Intimates', 'Skirts', 'Intimates', 'Fashion Hoodies & Sweatshirts'],
#  ['Maternity', 'Swim', 'Jumpsuits & Rompers', 'Plus', 'Blazers & Jackets'],
#  ['Plus', 'Jumpsuits & Rompers', 'Pants & Capris'],
#  ['Sweaters', 'Intimates', 'Leggings'],
#  ['Shorts', 'Intimates'],
#  ['Tops & Tees',
#   'Socks & Hosiery',
#   'Jeans',
#   'Blazers & Jackets',
#   'Sleep & Lounge',
#   'Socks & Hosiery'],
#  ['Skirts', 'Tops & Tees', 'Maternity'],
#  ['Dresses', 'Tops & Tees'],
#  ['Sleep & Lounge', 'Intimates', 'Jeans'],
#  ['Swim', 'Tops & Tees', 'Sleep & Lounge'],
#  ['Tops & Tees', 'Tops & Tees', 'Leggings'],
#  ['Tops & Tees'],
#  ['Jeans', 'Leggings', 'Sweaters', 'Intimates', 'Maternity', 'Intimates'],
#  ['Dresses', 'Jeans', 'Maternity', 'Intimates'],
#  ['Accessories', 'Dresses'],
#  ['Intimates', 'Intimates', 'Active', 'Shorts'],
#  ['Sleep & Lounge', 'Intimates'],
#  ['Intimates', 'Swim'],
#  ['Accessories',
#   'Shorts',
#   'Pants & Capris',
#   'Intimates',
#   'Maternity',
#   'Intimates'],
#  ['Sleep & Lounge', 'Tops & Tees'],
#  ['Fashion Hoodies & Sweatshirts', 'Swim'],
#  ['Jeans', 'Blazers & Jackets', 'Swim'],
#  ['Intimates'],
#  ['Fashion Hoodies & Sweatshirts', 'Sleep & Lounge', 'Outerwear & Coats'],
#  ['Sleep & Lounge', 'Shorts'],
#  ['Shorts', 'Swim', 'Jumpsuits & Rompers', 'Active', 'Dresses'],
#  ['Sleep & Lounge'],
#  ['Intimates', 'Sleep & Lounge', 'Tops & Tees', 'Active', 'Intimates'],
#  ['Active', 'Maternity', 'Outerwear & Coats'],
#  ['Plus',
#   'Maternity',
#   'Sleep & Lounge',
#   'Intimates',
#   'Sweaters',
#   'Sleep & Lounge'],
#  ['Accessories', 'Sweaters', 'Maternity'],
#  ['Socks & Hosiery'],
#  ['Maternity',
#   'Fashion Hoodies & Sweatshirts',
#   'Blazers & Jackets',
#   'Leggings',
#   'Intimates'],
#  ['Swim'],
#  ['Dresses',
#   'Sleep & Lounge',
#   'Maternity',
#   'Accessories',
#   'Maternity',
#   'Intimates'],
#  ['Tops & Tees',
#   'Sweaters',
#   'Sweaters',
#   'Jeans',
#   'Intimates',
#   'Maternity',
#   'Intimates'],
#  ['Maternity'],
#  ['Pants & Capris', 'Accessories'],
#  ['Intimates'],
#  ['Sleep & Lounge', 'Fashion Hoodies & Sweatshirts'],
#  ['Dresses', 'Maternity'],
#  ['Plus', 'Intimates'],
#  ['Skirts'],
#  ['Intimates', 'Fashion Hoodies & Sweatshirts', 'Sleep & Lounge'],
#  ['Outerwear & Coats', 'Intimates'],
#  ['Intimates'],
#  ['Plus', 'Active', 'Intimates', 'Intimates'],
#  ['Jeans', 'Socks & Hosiery'],
#  ['Jeans', 'Pants & Capris', 'Swim'],
#  ['Intimates', 'Jeans'],
#  ['Blazers & Jackets', 'Shorts', 'Outerwear & Coats'],
#  ['Dresses', 'Leggings'],
#  ['Intimates', 'Maternity', 'Pants & Capris', 'Fashion Hoodies & Sweatshirts'],
#  ['Blazers & Jackets', 'Sleep & Lounge'],
#  ['Accessories', 'Pants & Capris', 'Suits'],
#  ['Sweaters',
#   'Jeans',
#   'Shorts',
#   'Plus',
#   'Fashion Hoodies & Sweatshirts',
#   'Maternity'],
#  ['Socks & Hosiery', 'Intimates', 'Pants & Capris'],
#  ['Socks & Hosiery', 'Sleep & Lounge', 'Maternity'],
#  ['Blazers & Jackets', 'Intimates'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Fashion Hoodies & Sweatshirts',
#   'Plus',
#   'Intimates',
#   'Swim'],
#  ['Shorts', 'Intimates'],
#  ['Sleep & Lounge', 'Intimates'],
#  ['Socks & Hosiery', 'Intimates', 'Swim'],
#  ['Tops & Tees', 'Active', 'Sleep & Lounge'],
#  ['Maternity', 'Shorts'],
#  ['Fashion Hoodies & Sweatshirts', 'Fashion Hoodies & Sweatshirts'],
#  ['Leggings', 'Accessories'],
#  ['Maternity', 'Shorts'],
#  ['Pants & Capris', 'Intimates', 'Intimates'],
#  ['Fashion Hoodies & Sweatshirts'],
#  ['Sweaters', 'Intimates', 'Intimates'],
#  ['Fashion Hoodies & Sweatshirts', 'Dresses', 'Dresses', 'Swim', 'Active'],
#  ['Sweaters',
#   'Accessories',
#   'Blazers & Jackets',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Maternity'],
#  ['Dresses', 'Intimates', 'Plus'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Intimates',
#   'Outerwear & Coats',
#   'Blazers & Jackets',
#   'Active',
#   'Maternity'],
#  ['Fashion Hoodies & Sweatshirts', 'Intimates', 'Sleep & Lounge'],
#  ['Sweaters'],
#  ['Maternity', 'Intimates', 'Plus'],
#  ['Maternity', 'Sweaters'],
#  ['Socks & Hosiery', 'Swim'],
#  ['Skirts', 'Active', 'Outerwear & Coats', 'Outerwear & Coats'],
#  ['Dresses', 'Swim', 'Jeans', 'Shorts', 'Swim'],
#  ['Accessories', 'Intimates'],
#  ['Tops & Tees', 'Outerwear & Coats', 'Leggings', 'Blazers & Jackets'],
#  ['Outerwear & Coats', 'Active', 'Sleep & Lounge', 'Dresses'],
#  ['Jeans', 'Fashion Hoodies & Sweatshirts'],
#  ['Dresses', 'Skirts', 'Skirts'],
#  ['Active', 'Jeans', 'Intimates', 'Blazers & Jackets'],
#  ['Intimates', 'Outerwear & Coats', 'Intimates', 'Plus', 'Intimates'],
#  ['Swim', 'Blazers & Jackets', 'Intimates', 'Active'],
#  ['Outerwear & Coats', 'Blazers & Jackets', 'Leggings', 'Maternity'],
#  ['Fashion Hoodies & Sweatshirts', 'Dresses', 'Jeans'],
#  ['Swim'],
#  ['Dresses'],
#  ['Blazers & Jackets', 'Active'],
#  ['Tops & Tees',
#   'Tops & Tees',
#   'Intimates',
#   'Intimates',
#   'Intimates',
#   'Swim',
#   'Active'],
#  ['Shorts', 'Leggings'],
#  ['Dresses'],
#  ['Outerwear & Coats', 'Intimates'],
#  ['Intimates', 'Sleep & Lounge'],
#  ['Shorts', 'Fashion Hoodies & Sweatshirts', 'Leggings'],
#  ['Accessories', 'Tops & Tees', 'Maternity'],
#  ['Sweaters', 'Socks & Hosiery', 'Active', 'Blazers & Jackets'],
#  ['Accessories', 'Sleep & Lounge', 'Intimates', 'Plus', 'Intimates'],
#  ['Active', 'Active', 'Intimates'],
#  ['Active', 'Blazers & Jackets', 'Intimates', 'Tops & Tees'],
#  ['Jeans',
#   'Active',
#   'Fashion Hoodies & Sweatshirts',
#   'Accessories',
#   'Outerwear & Coats',
#   'Accessories'],
#  ['Shorts', 'Fashion Hoodies & Sweatshirts'],
#  ['Tops & Tees', 'Intimates', 'Socks & Hosiery', 'Plus'],
#  ['Maternity', 'Pants & Capris', 'Active', 'Dresses'],
#  ['Tops & Tees', 'Accessories', 'Outerwear & Coats'],
#  ['Dresses',
#   'Swim',
#   'Dresses',
#   'Fashion Hoodies & Sweatshirts',
#   'Blazers & Jackets'],
#  ['Maternity', 'Swim'],
#  ['Jeans', 'Outerwear & Coats'],
#  ['Dresses', 'Maternity', 'Dresses', 'Intimates'],
#  ['Jeans', 'Pants & Capris'],
#  ['Maternity', 'Jeans', 'Tops & Tees'],
#  ['Jeans', 'Maternity', 'Swim', 'Outerwear & Coats'],
#  ['Swim', 'Shorts'],
#  ['Pants & Capris', 'Sleep & Lounge', 'Sleep & Lounge'],
#  ['Maternity', 'Outerwear & Coats', 'Jeans', 'Sleep & Lounge', 'Intimates'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Active',
#   'Leggings',
#   'Accessories',
#   'Intimates',
#   'Sweaters'],
#  ['Tops & Tees',
#   'Intimates',
#   'Suits',
#   'Leggings',
#   'Intimates',
#   'Socks & Hosiery'],
#  ['Intimates', 'Fashion Hoodies & Sweatshirts'],
#  ['Maternity'],
#  ['Maternity', 'Shorts', 'Accessories'],
#  ['Suits', 'Pants & Capris', 'Intimates'],
#  ['Socks & Hosiery',
#   'Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Jeans',
#   'Intimates',
#   'Tops & Tees',
#   'Swim',
#   'Sweaters'],
#  ['Fashion Hoodies & Sweatshirts', 'Sweaters'],
#  ['Intimates', 'Skirts'],
#  ['Intimates', 'Leggings'],
#  ['Tops & Tees', 'Intimates', 'Fashion Hoodies & Sweatshirts', 'Leggings'],
#  ['Plus'],
#  ['Plus', 'Outerwear & Coats', 'Sleep & Lounge', 'Intimates'],
#  ['Dresses', 'Sweaters', 'Jeans', 'Outerwear & Coats'],
#  ['Maternity', 'Plus', 'Outerwear & Coats', 'Fashion Hoodies & Sweatshirts'],
#  ['Jeans', 'Fashion Hoodies & Sweatshirts'],
#  ['Maternity', 'Swim', 'Accessories', 'Accessories'],
#  ['Jeans', 'Fashion Hoodies & Sweatshirts'],
#  ['Sweaters'],
#  ['Fashion Hoodies & Sweatshirts', 'Active'],
#  ['Shorts', 'Sleep & Lounge'],
#  ['Dresses', 'Tops & Tees'],
#  ['Maternity', 'Dresses', 'Active'],
#  ['Accessories',
#   'Fashion Hoodies & Sweatshirts',
#   'Outerwear & Coats',
#   'Sleep & Lounge'],
#  ['Fashion Hoodies & Sweatshirts', 'Fashion Hoodies & Sweatshirts'],
#  ['Maternity', 'Blazers & Jackets', 'Intimates', 'Outerwear & Coats'],
#  ['Maternity',
#   'Dresses',
#   'Tops & Tees',
#   'Accessories',
#   'Blazers & Jackets',
#   'Dresses',
#   'Fashion Hoodies & Sweatshirts',
#   'Accessories',
#   'Pants & Capris'],
#  ['Blazers & Jackets', 'Sweaters', 'Dresses'],
#  ['Intimates', 'Jeans', 'Accessories', 'Accessories'],
#  ['Swim', 'Socks & Hosiery', 'Blazers & Jackets'],
#  ['Pants & Capris', 'Skirts', 'Sleep & Lounge', 'Maternity', 'Jeans'],
#  ['Intimates',
#   'Outerwear & Coats',
#   'Blazers & Jackets',
#   'Accessories',
#   'Tops & Tees',
#   'Jeans'],
#  ['Blazers & Jackets', 'Swim'],
#  ['Blazers & Jackets', 'Fashion Hoodies & Sweatshirts'],
#  ['Sweaters', 'Maternity', 'Intimates', 'Skirts'],
#  ['Intimates', 'Plus'],
#  ['Sweaters'],
#  ['Tops & Tees', 'Tops & Tees'],
#  ['Jeans', 'Intimates', 'Fashion Hoodies & Sweatshirts'],
#  ['Jeans', 'Socks & Hosiery', 'Socks & Hosiery', 'Blazers & Jackets', 'Plus'],
#  ['Outerwear & Coats', 'Active'],
#  ['Sleep & Lounge',
#   'Swim',
#   'Sweaters',
#   'Intimates',
#   'Blazers & Jackets',
#   'Leggings'],
#  ['Leggings', 'Plus', 'Intimates'],
#  ['Active', 'Socks & Hosiery'],
#  ['Dresses',
#   'Sleep & Lounge',
#   'Outerwear & Coats',
#   'Sweaters',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Active', 'Jeans', 'Sleep & Lounge'],
#  ['Jeans', 'Shorts'],
#  ['Intimates'],
#  ['Dresses', 'Plus', 'Intimates', 'Intimates', 'Sleep & Lounge'],
#  ['Suits'],
#  ['Clothing Sets', 'Dresses'],
#  ['Intimates',
#   'Fashion Hoodies & Sweatshirts',
#   'Fashion Hoodies & Sweatshirts',
#   'Maternity'],
#  ['Active',
#   'Blazers & Jackets',
#   'Tops & Tees',
#   'Socks & Hosiery',
#   'Plus',
#   'Socks & Hosiery'],
#  ['Plus', 'Jeans', 'Dresses', 'Shorts', 'Intimates'],
#  ['Swim'],
#  ['Accessories', 'Intimates'],
#  ['Intimates', 'Sweaters'],
#  ['Sleep & Lounge', 'Intimates'],
#  ['Shorts', 'Jeans', 'Intimates'],
#  ['Socks & Hosiery', 'Jeans'],
#  ['Socks & Hosiery', 'Maternity'],
#  ['Plus', 'Suits'],
#  ['Outerwear & Coats', 'Blazers & Jackets', 'Accessories', 'Suits'],
#  ['Active', 'Sweaters'],
#  ['Jeans', 'Accessories'],
#  ['Sweaters', 'Sweaters'],
#  ['Blazers & Jackets', 'Jeans', 'Swim', 'Maternity', 'Socks & Hosiery'],
#  ['Active', 'Leggings', 'Sleep & Lounge'],
#  ['Tops & Tees', 'Dresses', 'Maternity', 'Swim'],
#  ['Active',
#   'Accessories',
#   'Active',
#   'Active',
#   'Fashion Hoodies & Sweatshirts'],
#  ['Shorts', 'Shorts', 'Jeans'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Tops & Tees',
#   'Fashion Hoodies & Sweatshirts',
#   'Shorts'],
#  ['Outerwear & Coats',
#   'Leggings',
#   'Socks & Hosiery',
#   'Accessories',
#   'Accessories',
#   'Intimates',
#   'Sweaters'],
#  ['Intimates', 'Shorts'],
#  ['Socks & Hosiery',
#   'Socks & Hosiery',
#   'Accessories',
#   'Shorts',
#   'Dresses',
#   'Sleep & Lounge'],
#  ['Leggings', 'Active'],
#  ['Accessories', 'Socks & Hosiery'],
#  ['Sleep & Lounge',
#   'Fashion Hoodies & Sweatshirts',
#   'Tops & Tees',
#   'Pants & Capris',
#   'Active',
#   'Skirts'],
#  ['Fashion Hoodies & Sweatshirts',
#   'Outerwear & Coats',
#   'Swim',
#   'Pants & Capris',
#   'Intimates'],
#  ['Socks & Hosiery', 'Socks & Hosiery', 'Shorts', 'Jeans'],
#  ['Jeans', 'Suits'],
#  ['Intimates', 'Intimates', 'Leggings'],
#  ['Outerwear & Coats', 'Intimates', 'Dresses'],
#  ['Blazers & Jackets', 'Dresses'],
#  ['Pants & Capris', 'Accessories'],
#  ['Tops & Tees', 'Intimates'],
#  ['Tops & Tees', 'Intimates', 'Dresses', 'Dresses'],
#  ...]

# %%
len(user_sequences)
# Out:
# 10435

# %%
from prefixspan import PrefixSpan

ps = PrefixSpan(user_sequences)

# %%
ps.topk(20, closed=True, filter=lambda patt, matches: len(patt)>2)
# Out:
# [(121, ['Intimates', 'Intimates', 'Intimates']),
#  (58, ['Intimates', 'Intimates', 'Jeans']),
#  (58, ['Intimates', 'Maternity', 'Intimates']),
#  (54, ['Intimates', 'Intimates', 'Shorts']),
#  (54, ['Intimates', 'Intimates', 'Swim']),
#  (53, ['Intimates', 'Sleep & Lounge', 'Intimates']),
#  (52, ['Intimates', 'Dresses', 'Intimates']),
#  (51, ['Intimates', 'Fashion Hoodies & Sweatshirts', 'Intimates']),
#  (51, ['Intimates', 'Tops & Tees', 'Intimates']),
#  (50, ['Intimates', 'Intimates', 'Sweaters']),
#  (48, ['Intimates', 'Intimates', 'Active']),
#  (47, ['Intimates', 'Intimates', 'Dresses']),
#  (46, ['Accessories', 'Intimates', 'Intimates']),
#  (46, ['Tops & Tees', 'Intimates', 'Intimates']),
#  (45, ['Dresses', 'Intimates', 'Intimates']),
#  (45, ['Intimates', 'Intimates', 'Fashion Hoodies & Sweatshirts']),
#  (45, ['Intimates', 'Intimates', 'Tops & Tees']),
#  (45, ['Jeans', 'Intimates', 'Intimates']),
#  (44, ['Sleep & Lounge', 'Intimates', 'Intimates']),
#  (43, ['Intimates', 'Accessories', 'Intimates'])]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
order_items_filtered = order_items_enriched.loc[order_items_enriched.user_id.isin(repeat_purchasers_idx)]\
                                          .loc[~order_items_enriched.status.isin(['Cancelled', 'Returned'])]

user_sets = order_items_filtered.groupby('user_id')['product_category'].apply(lambda x: list(set(x))).tolist()

# %%
te = TransactionEncoder()
te_arr = te.fit(user_sets).transform(user_sets)
apriori_df = pd.DataFrame(te_arr, columns=te.columns_)
apriori_results = apriori(apriori_df, min_support=0.025, use_colnames=True)

# %%
apriori_results
# Out:
#      support                                         itemsets
# 0   0.151711                                    (Accessories)
# 1   0.141075                                         (Active)
# 2   0.053085                              (Blazers & Jackets)
# 3   0.087072                                        (Dresses)
# 4   0.184104                  (Fashion Hoodies & Sweatshirts)
# 5   0.188600                                      (Intimates)
# 6   0.193725                                          (Jeans)
# 7   0.050957                                       (Leggings)
# 8   0.084558                                      (Maternity)
# 9   0.138368                              (Outerwear & Coats)
# 10  0.109988                                          (Pants)
# 11  0.054970                                 (Pants & Capris)
# 12  0.067734                                           (Plus)
# 13  0.169551                                         (Shorts)
# 14  0.035680                                         (Skirts)
# 15  0.167908                                 (Sleep & Lounge)
# 16  0.095388                                          (Socks)
# 17  0.063044                                (Socks & Hosiery)
# 18  0.081996                            (Suits & Sport Coats)
# 19  0.172162                                       (Sweaters)
# 20  0.176368                                           (Swim)
# 21  0.182653                                    (Tops & Tees)
# 22  0.111632                                      (Underwear)
# 23  0.026446     (Accessories, Fashion Hoodies & Sweatshirts)
# 24  0.028718                             (Accessories, Jeans)
# 25  0.025962                          (Accessories, Sweaters)
# 26  0.026059                              (Accessories, Swim)
# 27  0.027461                       (Accessories, Tops & Tees)
# 28  0.026639                                  (Active, Jeans)
# 29  0.025914                            (Active, Tops & Tees)
# 30  0.029733                             (Intimates, Dresses)
# 31  0.030265       (Intimates, Fashion Hoodies & Sweatshirts)
# 32  0.034229           (Jeans, Fashion Hoodies & Sweatshirts)
# 33  0.028766          (Shorts, Fashion Hoodies & Sweatshirts)
# 34  0.027654  (Fashion Hoodies & Sweatshirts, Sleep & Lounge)
# 35  0.031474        (Fashion Hoodies & Sweatshirts, Sweaters)
# 36  0.031619            (Fashion Hoodies & Sweatshirts, Swim)
# 37  0.033021     (Fashion Hoodies & Sweatshirts, Tops & Tees)
# 38  0.027751                               (Intimates, Jeans)
# 39  0.028573                           (Intimates, Maternity)
# 40  0.026301                      (Intimates, Sleep & Lounge)
# 41  0.027654                                (Intimates, Swim)
# 42  0.025624                         (Intimates, Tops & Tees)
# 43  0.025672                       (Jeans, Outerwear & Coats)
# 44  0.030458                                  (Shorts, Jeans)
# 45  0.030845                          (Jeans, Sleep & Lounge)
# 46  0.031135                                (Jeans, Sweaters)
# 47  0.033311                                    (Jeans, Swim)
# 48  0.034181                             (Jeans, Tops & Tees)
# 49  0.025720                 (Outerwear & Coats, Tops & Tees)
# 50  0.026446                         (Shorts, Sleep & Lounge)
# 51  0.028186                               (Shorts, Sweaters)
# 52  0.028379                                   (Shorts, Swim)
# 53  0.030313                            (Shorts, Tops & Tees)
# 54  0.026929                       (Sleep & Lounge, Sweaters)
# 55  0.029153                           (Sleep & Lounge, Swim)
# 56  0.028476                    (Sleep & Lounge, Tops & Tees)
# 57  0.030555                                 (Sweaters, Swim)
# 58  0.030990                          (Sweaters, Tops & Tees)
# 59  0.030023                              (Swim, Tops & Tees)
